# %%
search_params = {
    "collections": ["sentinel-2-l2a"],
    "datetime": "2024-12-06T00:00:00Z/2025-01-06T23:59:59Z",
    "query": {"eo:cloud_cover": {"lt": 30}},
    "bbox": [83.9627230167389, 28.199165271853364, 83.96748661994936, 28.202105871401734],
    "limit": 100,
}
